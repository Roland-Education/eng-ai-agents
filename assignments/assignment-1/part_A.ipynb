# %% [markdown]
# <a href="https://colab.research.google.com/github/rolandchi/eng-ai-agents/blob/main/part_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Docker Container IDE - Screenshot.png](data:image/png;base64,...)

# %% [markdown]
# ![Hugging Face Account - Roland Chi - Screenshot.png](data:image/png;base64,...)
